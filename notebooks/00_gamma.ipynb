# %% [markdown]
# Section 1 — Why Gamma Exists
#
# Displays are nonlinear devices.
# Human vision is also nonlinear.

# %% [markdown]
# Section 2 — Mathematical Model
#
# $$
# V_{\text{linear}} =
# \begin{cases}
# \frac{V}{12.92} , & V \leq 0.04045 \\
# \left(\frac{V + 0.055}{1.055}\right)^{2.4}, & V > 0.04045
# \end{cases}
# $$

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from src.gamma.gamma_curve import plot_gamma_curve


plot_gamma_curve()
